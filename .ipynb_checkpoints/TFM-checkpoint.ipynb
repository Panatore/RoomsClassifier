# %% [markdown]
# # Room Classifier by Daniel Collado

# %% [markdown]
# ## Import Data and libraries

# %% [markdown]
# Import all librarys we need during the notebook

# %%
import tensorflow as tf
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Activation, Dropout, Flatten, Dense
from keras.layers import Rescaling
from keras.preprocessing.image import ImageDataGenerator
from keras.applications.imagenet_utils import preprocess_input
import scipy
from keras.applications import MobileNetV2, VGG16, InceptionV3
from keras.layers import GlobalAveragePooling2D
from keras.models import Model
from keras.losses import categorical_crossentropy
from keras.utils import load_img, img_to_array
from keras.models import load_model
from keras.optimizers import Adam, SGD
from sklearn.metrics import confusion_matrix
import os

# %% [markdown]
# Check if tensorflow is using the GPU

# %%
if  len(tf.config.list_physical_devices('GPU')) > 0:
    print("Tensorflow is using your GPU to process the data")

# %% [markdown]
# #### Load the data of the directory

# %% [markdown]
# Load the path of the data directories. In case you are loading this notebook using Google Colab and you have the data unzip in your google Drive, uncomment the code and change the uncommented code to comments.

# %%
#Uncomment this in case you charge this in a google colab notebook
# from google.colab import drive
# drive.mount('/content/drive')
# data_dir = "/content/drive/data/Train"
# test_dir = "/content/drive/data/Test"

data_dir = "./data/Train/"
test_dir = "./data/Test"

# %% [markdown]
# Split the data in 2 dataset: 1 for train and another for validation. We use a seed to produce the same results every time the code is run and a batch size of 32 to reduce the memory requirement.

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(256,256),
  batch_size=32)
# Out:
# Found 4070 files belonging to 5 classes.
# Using 3256 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(256,256),
  batch_size=32)
# Out:
# Found 4070 files belonging to 5 classes.
# Using 814 files for validation.

# %% [markdown]
# We have 5 different classes that we are going to try to predict using the model created. We are going to create here to varibles that we are going to use lately for creating the models or to make predictions.

# %%
class_names = train_ds.class_names
num_classes = len(class_names)
print(f'This is the list of the names of all classes {class_names}')
# Out:
# This is the list of the names of all classes ['Bathroom', 'Bedroom', 'House Map', 'Kitchen', 'Living Room']

# %% [markdown]
# ## Dataset exploration

# %% [markdown]
# Show a sample of the 9 first images with their own labels

# %%
plt.figure(figsize=(10, 10))
# Create a loop using a batch of the train data set and plot each image in each row and column
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# We see that the each batch have 32 images and each image have the dimensions of (256,256,3) where 3 mean the RGB of each pixel

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 256, 256, 3)
# (32,)

# %% [markdown]
# Lets show how much images we have in the training for class

# %%
# Obtain a list of each folder of the directory
folders = os.listdir(data_dir)

# Arrays to store the folder names and number of files in each
folder_names = []
num_files = []

# Loop through the list and count the number of files in each folder
for item in folders:
    if os.path.isdir(os.path.join(data_dir, item)):
        # Get a list of all files in the folder
        files_in_folder = os.listdir(os.path.join(data_dir, item))
        # Count the number of files in the folder
        count = len([f for f in files_in_folder if os.path.isfile(os.path.join(data_dir, item, f))])
        # Add the folder name and number of files to the arrays
        folder_names.append(item)
        num_files.append(count)

# Create the horizontal bar chart
plt.barh(folder_names, num_files)

# Show the chart
plt.show()

# %% [markdown]
# ## Preprocess data

# %% [markdown]
# Scale the image dividing it by 255

# %%
normalization_layer = Rescaling(1./255)

# %%
normalized_train_ds = train_ds.map(lambda x, y: (normalization_layer(x),y))
normalized_valid_ds = val_ds.map(lambda x, y: (normalization_layer(x),y))
image_batch, labels_batch = next(iter(normalized_train_ds))
first_image = image_batch[0]
#Print the min and max to check if is right normalized [0,1] 
print(np.min(first_image),np.max(first_image))
# Out:
# 0.011127547 1.0

# %% [markdown]
# ## Train the models

# %% [markdown]
# ### Model trained using convolutional neural network

# %% [markdown]
# This function defines a convolutional neural network (CNN) model using the Sequential API from the Keras library. The model takes in an input shape as an argument, which is used in the first layer of the model (Conv2D(32,(3,3),input_shape = input_shape)). The model is composed of several layers:
#
# - First, it has a series of 2D convolutional layers (Conv2D) with different number of filters (32, 32, 64) and kernel size (3,3) which applies convolution operation on the input image with the set of filters.
# - Then it has a series of activation layers (Activation("relu")) which applies the ReLU activation function on the output of the corresponding convolutional layer.
# - Then it has a series of max pooling layers (MaxPooling2D()) which reduces the spatial dimension of the image by taking the maximum value of a group of pixels and downsampling the image.
# - Then it has a flatten layer (Flatten()) which flatten the output from the previous layers to 1D array.
# - Then it has a series of dense layers (Dense) which are fully connected layers in the neural network with 1024 units in the first and num_classes (number of classes) in the last dense layer.
# - Then it has a series of dropout layer (Dropout(0.5)) which is used to drop out a random set of activations in that layer by setting them to zero during training time to prevent overfitting.
# - Finally, it has a output layer (Activation("softmax")) which applies the softmax activation function to the output of the last dense layer to output the probability of each class.
#
# The function returns the model object which can be used for further training and evaluation.

# %%
#Create a function with the input shape as an input that creates a convulotional model with all the layers need it
def def_conv_model(input_shape):
    model = Sequential()
    model.add(Conv2D(32,(3,3),input_shape = input_shape))
    model.add(Activation("relu"))
    model.add(MaxPooling2D())

    model.add(Conv2D(32,(3,3)))
    model.add(Activation("relu"))
    model.add(MaxPooling2D())

    model.add(Conv2D(64,(3,3)))
    model.add(Activation("relu"))
    model.add(MaxPooling2D())

    model.add(Flatten())
    model.add(Dense(1024))
    model.add(Activation("relu"))
    model.add(Dropout(0.5))
    model.add(Dense(num_classes)) # output
    model.add(Activation("softmax"))
    return model

# %%
conv_model = def_conv_model(input_shape=(256,256,3))

# %% [markdown]
#  The Adam optimizer is a gradient-based optimization algorithm that adapts the learning rate for each parameter, which can help to improve the convergence of the training process.
#
# The SparseCategoricalCrossentropy loss function is commonly used for multi-class classification problems where the classes are exclusive. In a room classification problem, where you are trying to predict the type of room based on an image, the classes (e.g., bedroom, living room, kitchen, etc.) are exclusive, meaning that an image can only belong to one class. Therefore, using the SparseCategoricalCrossentropy loss function is appropriate for this task.
#
# As for the metrics, accuracy is a widely used metric for multi-class classification problems. It calculates the proportion of correct predictions made by the model. In this case, it will give an idea of how many of the room images are classified correctly by the model. However, accuracy can be misleading in case of unbalanced data, when one class is much more frequent than others.

# %%
conv_model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
tf.keras.utils.plot_model(conv_model, to_file ="/model.png",show_shapes = True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
conv_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 32)      896
#
#  activation (Activation)     (None, 254, 254, 32)      0
#
#  max_pooling2d (MaxPooling2D  (None, 127, 127, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 32)      9248
#
#  activation_1 (Activation)   (None, 125, 125, 32)      0
#
#  max_pooling2d_1 (MaxPooling  (None, 62, 62, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 64)        18496
#
#  activation_2 (Activation)   (None, 60, 60, 64)        0
#
#  max_pooling2d_2 (MaxPooling  (None, 30, 30, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 57600)             0
#
#  dense (Dense)               (None, 1024)              58983424
#
#  activation_3 (Activation)   (None, 1024)              0
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None,
# Epoch 19/20
# 102/102 [==============================] - 9s 82ms/step - loss: 0.0283 - accuracy: 0.9945 - val_loss: 2.3540 - val_accuracy: 0.5799
# Epoch 20/20
# 102/102 [==============================] - 9s 83ms/step - loss: 0.0220 - accuracy: 0.9951 - val_loss: 2.2593 - val_accuracy: 0.5897

# %%
def plot_history(history,epochs = 20):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']

    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs_range = range(epochs)

    plt.figure(figsize=(8, 8))
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.show()

# %%
plot_history(conv_hist)

# %% [markdown]
# ### Model with convolutional neural network using image data generator

# %% [markdown]
# We modify the width and height shape of the data images beacuse the input layer used in transfer learning uses that.

# %%
width_shape = 224
height_shape = 224
epochs = 50
batch_size = 32

# %% [markdown]
# We are going to apply the Image Data Generator keras function to modify the images of the training dataset applying some random zoom , some shear and a random horizontal flip because the photographs uploaded by the user will be usual people not professional photographer.
# In the validation dataset we only rescale as we did before.
# - Random Zoom
# - Shear Range
# - Horinzontal flip
# - Width and height shift

# %%
train_datagen = ImageDataGenerator( 
    rescale= 1./255,
    zoom_range=0.2,
    shear_range= 0.2,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    validation_split= 0.2)


valid_datagen = ImageDataGenerator(rescale= 1./255, validation_split= 0.2)

train_generator = train_datagen.flow_from_directory(data_dir,
    target_size=(width_shape, height_shape),
    color_mode="rgb",
    class_mode='categorical',
    subset= "training",
    seed= 123,
    batch_size= batch_size)

valid_generator = valid_datagen.flow_from_directory(data_dir,
    target_size=(width_shape, height_shape),
    color_mode="rgb",
    seed= 123,
    class_mode='categorical',
    subset= "validation",
    batch_size= batch_size)
# Out:
# Found 3258 images belonging to 5 classes.
# Found 812 images belonging to 5 classes.

# %% [markdown]
# We print all classes and the first value to verify is correct

# %%
print(train_generator.class_indices)
print(train_generator.next()[0][1])
# Out:
# {'Bathroom': 0, 'Bedroom': 1, 'House Map': 2, 'Kitchen': 3, 'Living Room': 4}
# [[[0.7960785  0.7960785  0.80392164]
#   [0.7960785  0.7960785  0.80392164]
#   [0.7960785  0.7960785  0.80392164]
#   ...
#   [0.67058825 0.6745098  0.68235296]
#   [0.67058825 0.6745098  0.68235296]
#   [0.67058825 0.6745098  0.68235296]]
#
#  [[0.7960785  0.7960785  0.80392164]
#   [0.7960785  0.7960785  0.80392164]
#   [0.7960785  0.7960785  0.80392164]
#   ...
#   [0.67058825 0.6745098  0.68235296]
#   [0.67058825 0.6745098  0.68235296]
#   [0.67058825 0.6745098  0.68235296]]
#
#  [[0.7960785  0.7960785  0.80392164]
#   [0.7960785  0.7960785  0.80392164]
#   [0.7960785  0.7960785  0.80392164]
#   ...
#   [0.67058825 0.6745098  0.68235296]
#   [0.67058825 0.6745098  0.68235296]
#   [0.67058825 0.6745098  0.68235296]]
#
#  ...
#
#  [[0.7426883  0.70347255 0.6956294 ]
#   [0.7411765  0.7019608  0.69411767]
#   [0.7391493  0.6999336  0.69209045]
#   ...
#   [0.5647059  0.5058824  0.4784314 ]
#   [0.5647059  0.5058824  0.4784314 ]
#   [0.5647059  0.5058824  0.4784314 ]]
#
#  [[0.74508005 0.70586437 0.69802123]
#   [0.7431827  0.70396703 0.6961239 ]
#   [0.7411546  0.7019389  0.6940958 ]
#   ...
#   [0.5687183  0.5098948  0.4824438 ]
#   [0.5687183  0.5098948  0.4824438 ]
#   [0.5687183  0.5098948  0.4824438 ]]
#
#  [[0.75203973 0.71282405 0.7049809 ]
#   [0.7490196  0.70980394 0.7019608 ]
#   [0.74699074 0.707775   0.69993186]
#   ...
#   [0.5803922  0.52156866 0.49411768]
#   [0.5803922  0.52156866 0.49411768]
#   [0.5803922  0.52156866 0.49411768]]]

# %% [markdown]
# Plot examples of the images with data image generator

# %%
batch =  train_generator.next()
  
plt.figure(figsize=(10, 10))

for i in range(6):
  ax = plt.subplot(3, 2, i + 1)
  plt.imshow(batch[0][i])
  plt.title(class_names[np.argmax(batch[1][i])])
  plt.axis("off")

# %%
model_conv_with_data_gen = def_conv_model(input_shape=(224,224,3))

# %%
model_conv_with_data_gen.compile(optimizer = 'adam', loss = categorical_crossentropy, metrics = ['accuracy'] )

conv_hist_with_data_generator = model_conv_with_data_gen.fit(train_generator,
                           epochs = epochs,
                           validation_data= valid_generator
                           )
# Out:
# Epoch 1/50
#  19/102 [====>.........................] - ETA: 42s - loss: 2.3734 - accuracy: 0.2253
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\danie\OneDrive\Documentos\GitHub\RoomsClassifier\TFM.ipynb Cell 42 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/danie/OneDrive/Documentos/GitHub/RoomsClassifier/TFM.ipynb#X56sZmlsZQ%3D%3D?line=0'>1</a> model_conv_with_data_gen.compile(optimizer = 'adam', loss = categorical_crossentropy, metrics = ['accuracy'] )
# ----> <a href='vscode-notebook-cell:/c%3A/Users/danie/OneDrive/Documentos/GitHub/RoomsClassifier/TFM.ipynb#X56sZmlsZQ%3D%3D?line=2'>3</a> conv_hist_with_data_generator = model_conv_with_data_gen.fit(train_generator,
#       <a href='vscode-notebook-cell:/c%3A/Users/danie/OneDrive/Documentos/GitHub/RoomsClassifier/TFM.ipynb#X56sZmlsZQ%3D%3D?line=3'>4</a>                            epochs = epochs,
#       <a href='vscode-notebook-cell:/c%3A/Users/danie/OneDrive/Documentos/GitHub/RoomsClassifier/TFM.ipynb#X56sZmlsZQ%3D%3D?line=4'>5</a>                            validation_data= valid_generator
#       <a href='vscode-notebook-cell:/c%3A/Users/danie/OneDrive/Documentos/GitHub/RoomsClassifier/TFM.ipynb#X56sZmlsZQ%3D%3D?line=5'>6</a>                            )
#
# File c:\Users\danie\miniconda3\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\danie\miniconda3\lib\site-packages\keras\engine\training.py:1564, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1556 with tf.profiler.experimental.Trace(
#    1557     "train",
#    1558     epoch_num=epoch,
#    (...)
#    1561     _r=1,
#    1562 ):
#    1563     callbacks.on_train_batch_begin(step)
# -> 1564     tmp_logs = self.train_function(iterator)
#    1565     if data_handler.should_sync:
#    1566         context.async_wait()
#
# File c:\Users\danie\miniconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\danie\miniconda3\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\danie\miniconda3\lib\site-packages\tensorflow\python\eager\def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File c:\Users\danie\miniconda3\lib\site-packages\tensorflow\python\eager\function.py:2496, in Function.__call__(self, *args, **kwargs)
#    2493 with self._lock:
#    2494   (graph_function,
#    2495    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2496 return graph_function._call_flat(
#    2497     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File c:\Users\danie\miniconda3\lib\site-packages\tensorflow\python\eager\function.py:1862, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1858 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1859 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1860     and executing_eagerly):
#    1861   # No tape is watching; skip to running the function.
# -> 1862   return self._build_call_outputs(self._inference_function.call(
#    1863       ctx, args, cancellation_manager=cancellation_manager))
#    1864 forward_backward = self._select_forward_and_backward_functions(
#    1865     args,
#    1866     possible_gradient_type,
#    1867     executing_eagerly)
#    1868 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\danie\miniconda3\lib\site-packages\tensorflow\python\eager\function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File c:\Users\danie\miniconda3\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
plot_history(conv_hist_with_data_generator)

# %% [markdown]
# ### Defining a function to train a model using a pretrained model with a transfer learning technique

# %%
def train_transfer_learning_model(base_model):
  #Define the variables
  epochs = 15
  # Freeze base model layers
  for layer in base_model.layers:
    layer.trainable = False

  # Add new layers connected to the base model
  x=base_model.output
  x=GlobalAveragePooling2D()(x)
  x=Dense(1024,activation='relu')(x) #we add dense layers so that the model can learn more complex functions and classify for better results.
  x=Dense(1024,activation='relu')(x) #dense layer 2
  x=Dense(512,activation='relu')(x) #dense layer 3
  x = Dropout(0.5)(x)
  predictions=Dense(num_classes,activation='softmax')(x) #final layer with softmax activation

  # Create a model using the pretrained model
  transfer_learning_model = Model(inputs=base_model.input, outputs=predictions)

  # Compile the model using SGD
  transfer_learning_model.compile(optimizer=SGD(lr=0.001, momentum=0.9), loss='categorical_crossentropy', metrics=['accuracy'])

  # Train the model
  transfer_learning_hist = transfer_learning_model.fit(
        train_generator,
        steps_per_epoch=train_generator.samples/train_generator.batch_size ,
        epochs= epochs,
        validation_data=valid_generator,
        validation_steps=valid_generator.samples/valid_generator.batch_size,
        verbose=1)

  # Unfreeze all the layers of the model
  for layer in base_model.layers:
    layer.trainable = True

  # Compile the model but using a low learning rate
  transfer_learning_model.compile(optimizer=SGD(lr=0.0001, momentum= 0.9), loss='categorical_crossentropy', metrics=['accuracy'])

  # Train the model again
  fine_tuning_hist = transfer_learning_model.fit(
        train_generator,
        steps_per_epoch=train_generator.samples/train_generator.batch_size ,
        epochs= epochs,
        validation_data=valid_generator,
        validation_steps=valid_generator.samples/valid_generator.batch_size,
        verbose=1)
  
  print("This is the historical of the transfer learning")
  plot_history(transfer_learning_hist,epochs)

  print("This is the historical of the fine tuning")
  plot_history(fine_tuning_hist,epochs)  

  return transfer_learning_model

# %% [markdown]
# ### Transfer learning using MobileNetV2 model

# %%
mobile_base=MobileNetV2(weights='imagenet',include_top=False) #imports the mobilenet model without the input layer

mobilenet_model = train_transfer_learning_model(mobile_base)
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# c:\Users\danie\miniconda3\lib\site-packages\keras\optimizers\optimizer_v2\gradient_descent.py:111: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Epoch 1/15
#  74/101 [====================>.........] - ETA: 10s - loss: 1.1908 - accuracy: 0.5215
# c:\Users\danie\miniconda3\lib\site-packages\PIL\Image.py:959: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# 101/101 [==============================] - 43s 400ms/step - loss: 1.0719 - accuracy: 0.5761 - val_loss: 0.5754 - val_accuracy: 0.8017
# Epoch 2/15
# 101/101 [==============================] - 41s 393ms/step - loss: 0.6026 - accuracy: 0.7772 - val_loss: 0.3986 - val_accuracy: 0.8473
# Epoch 3/15
# 101/101 [==============================] - 40s 397ms/step - loss: 0.4987 - accuracy: 0.8161 - val_loss: 0.3593 - val_accuracy: 0.8633
# Epoch 4/15
# 101/101 [==============================] - 40s 389ms/step - loss: 0.4519 - accuracy: 0.8379 - val_loss: 0.3391 - val_accuracy: 0.8756
# Epoch 5/15
# 101/101 [==============================] - 40s 388ms/step - loss: 0.4196 - accuracy: 0.8502 - val_loss: 0.3322 - val_accuracy: 0.8768
# Epoch 6/15
# 101/101 [==============================] - 40s 386ms/step - loss: 0.4062 - accuracy: 0.8527 - val_loss: 0.3195 - val_accuracy: 0.8744
# Epoch 7/15
# 101/101 [==============================] - 40s 392ms/step - loss: 0.3925 - accuracy: 0.8653 - val_loss: 0.3432 - val_accuracy: 0.8534
# Epoch 8/15
# 101/101 [==============================] - 39s 382ms/step - loss: 0.3774 - accuracy: 0.8622 - val_loss: 0.3126 - val_accuracy: 0.8682
# Epoch 9/15
# 101/101 [==============================] - 38s 369ms/step - loss: 0.3512 - accuracy: 0.8705 - val_loss: 0.2969 - val_accuracy: 0.8818
# 101/101 [==============================] - 38s 371ms/step - loss: 0.2565 - accuracy: 0.9104 - val_loss: 0.2663 - val_accuracy: 0.9015
# Epoch 14/15
# 101/101 [==============================] - 38s 369ms/step - loss: 0.2285 - accuracy: 0.9147 - val_loss: 0.2612 - val_accuracy: 0.9002
# Epoch 15/15
# 101/101 [==============================] - 38s 369ms/step - loss: 0.2224 - accuracy: 0.9205 - val_loss: 0.2537 - val_accuracy: 0.9064
# This is the historical of the transfer learning
# This is the historical of the fine tuning

# %%
mobilnet_results = mobilenet_model.evaluate_generator(valid_generator)
print("Loss: ",mobilnet_results[0])
print("Accuracy: ", mobilnet_results[1])
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_16284\270682978.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   mobilnet_results = mobilenet_model.evaluate_generator(valid_generator)
# Loss:  0.2536853551864624
# Accuracy:  0.9064039587974548

# %% [markdown]
# ### Transfer learning using VGG16 model

# %%
vgg_base=VGG16(weights='imagenet',include_top=False) #imports the VGG model without the input layer

vgg_model = train_transfer_learning_model(vgg_base)
# Out:
# Epoch 1/15
# 101/101 [==============================] - 48s 424ms/step - loss: 1.4978 - accuracy: 0.3085 - val_loss: 1.3658 - val_accuracy: 0.3867
# Epoch 2/15
# 101/101 [==============================] - 38s 372ms/step - loss: 1.3525 - accuracy: 0.4196 - val_loss: 1.2089 - val_accuracy: 0.5320
# Epoch 3/15
# 101/101 [==============================] - 38s 373ms/step - loss: 1.2433 - accuracy: 0.4736 - val_loss: 1.0909 - val_accuracy: 0.5493
# Epoch 4/15
# 101/101 [==============================] - 38s 372ms/step - loss: 1.1516 - accuracy: 0.5273 - val_loss: 1.0034 - val_accuracy: 0.5985
# Epoch 5/15
# 101/101 [==============================] - 38s 376ms/step - loss: 1.0893 - accuracy: 0.5531 - val_loss: 0.9428 - val_accuracy: 0.6355
# Epoch 6/15
# 101/101 [==============================] - 38s 375ms/step - loss: 1.0355 - accuracy: 0.5749 - val_loss: 0.9109 - val_accuracy: 0.6367
# Epoch 7/15
# 101/101 [==============================] - 38s 374ms/step - loss: 0.9937 - accuracy: 0.5899 - val_loss: 0.8459 - val_accuracy: 0.6823
# Epoch 8/15
# 101/101 [==============================] - 38s 372ms/step - loss: 0.9460 - accuracy: 0.6068 - val_loss: 0.8473 - val_accuracy: 0.6552
# Epoch 9/15
# 101/101 [==============================] - 38s 376ms/step - loss: 0.9240 - accuracy: 0.6280 - val_loss: 0.8184 - val_accuracy: 0.6478
# Epoch 10/15
# 101/101 [==============================] - 38s 375ms/step - loss: 0.9018 - accuracy: 0.6357 - val_loss: 0.8333 - val_accuracy: 0.6318
# Epoch 11/15
# 101/101 [==============================] - 38s 377ms/step - loss: 0.8875 - accuracy: 0.6344 - val_loss: 0.7476 - val_accuracy: 0.6872
# Epoch 12/15
# 101/101 [==============================] - 38s 373ms/step - loss: 0.8639 - accuracy: 0.6479 - val_loss: 0.7751 - val_accuracy: 0.6798
# Epoch 13/15
# 101/101 [==============================] - 38s 374ms/step - loss: 0.8440 - accuracy: 0.6593 - val_loss: 0.7580 - val_accuracy: 0.6650
# Epoch 3/15
# 101/101 [==============================] - 38s 375ms/step - loss: 0.7441 - accuracy: 0.7274 - val_loss: 0.4949 - val_accuracy: 0.8202
# Epoch 4/15
# 101/101 [==============================] - 35s 344ms/step - loss: 0.6207 - accuracy: 0.7744 - val_loss: 0.4437 - val_accuracy: 0.8436
# Epoch 5/15
# 101/101 [==============================] - 38s 375ms/step - loss: 0.5564 - accuracy: 0.7953 - val_loss: 0.4037 - val_accuracy: 0.8485
# Epoch 6/15
# 101/101 [==============================] - 38s 374ms/step - loss: 0.5158 - accuracy: 0.8204 - val_loss: 0.3737 - val_accuracy: 0.8608
# Epoch 7/15
# 101/101 [==============================] - 38s 373ms/step - loss: 0.4685 - accuracy: 0.8324 - val_loss: 0.3414 - val_accuracy: 0.8695
# Epoch 8/15
# 101/101 [==============================] - 38s 375ms/step - loss: 0.4615 - accuracy: 0.8297 - val_loss: 0.3141 - val_accuracy: 0.8793
# Epoch 9/15
# 101/101 [==============================] - 38s 374ms/step - loss: 0.4163 - accuracy: 0.8438 - val_loss: 0.3060 - val_accuracy: 0.8855
# Epoch 10/15
# 101/101 [==============================] - 38s 377ms/step - loss: 0.3777 - accuracy: 0.8597 - val_loss: 0.3015 - val_accuracy: 0.8879
# Epoch 11/15
# 101/101 [==============================] - 39s 377ms/step - loss: 0.3715 - accuracy: 0.8603 - val_loss: 0.2812 - val_accuracy: 0.8953
# Epoch 12/15
# 101/101 [==============================] - 39s 380ms/step - loss: 0.3528 - accuracy: 0.8732 - val_loss: 0.2680 - val_accuracy: 0.9027
# Epoch 13/15
# 101/101 [==============================] - 41s 404ms/step - loss: 0.3380 - accuracy: 0.8769 - val_loss: 0.2671 - val_accuracy: 0.8929
# Epoch 14/15
# 101/101 [==============================] - 40s 389ms/step - loss: 0.3160 - accuracy: 0.8898 - val_loss: 0.2492 - val_accuracy: 0.9113
# Epoch 15/15
# 101/101 [==============================] - 39s 383ms/step - loss: 0.3032 - accuracy: 0.8877 - val_loss: 0.2467 - val_accuracy: 0.9113
# This is the historical of the transfer learning
# This is the historical of the fine tuning

# %%
inception_results = inception_model.evaluate_generator(valid_generator)
print("Loss: ",inception_results[0])
print("Accuracy: ", inception_results[1])
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_16284\2662452695.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   inception_results = inception_model.evaluate_generator(valid_generator)
# Loss:  0.24665914475917816
# Accuracy:  0.9113300442695618

# %% [markdown]
# ### Save the VGG model the one that have the best accuracy

# %%
vgg_model.save(filepath="Models\model_transfer_learning\model_transfer_learning.h5", overwrite= True) #Save best transfer model learning VGG

# %%
vgg_model = load_model("Models\model_transfer_learning\model_transfer_learning.h5")

# %% [markdown]
# #### Load images and test if the prediction of the model is correct

# %%
def load_image(img_path, show=False):


    img = load_img(img_path, target_size=(width_shape, height_shape))
    img_tensor =    img_to_array(img)                    # (height, width, channels)
    img_tensor = np.expand_dims(img_tensor, axis=0)         # (1, height, width, channels), add a dimension because the model expects this shape: (batch_size, height, width, channels)
    img_tensor /= 255.  
    if show:
        plt.imshow(img_tensor[0])                           
        plt.axis('off')
        plt.show()

    return img_tensor

# %%
rel_path = r'Bathroom\25.jpg'
img_path = os.path.join(test_dir,rel_path)
new_image = load_image(img_path,show=True)

pred = vgg_model.predict(new_image)

print(pred)

print(f'The prediction is {class_names[np.argmax(pred)]}')
# Out:
# 1/1 [==============================] - 0s 21ms/step
# [[2.3151204e-02 7.2165385e-05 3.4076178e-03 9.7141379e-01 1.9551450e-03]]
# The prediction is Kitchen

# %%
rel_path = r'Bedroom\20.jpg'
img_path = os.path.join(test_dir,rel_path)
new_image = load_image(img_path,show=True)

pred = vgg_model.predict(new_image)

print(f'The prediction is {class_names[np.argmax(pred)]}')
# Out:
# 1/1 [==============================] - 0s 24ms/step
# The prediction is Living Room

# %% [markdown]
# ## Model evaluation

# %% [markdown]
# Load test data and evaluate the model with new data

# %%
test_datagen = ImageDataGenerator(rescale= 1./255)


test_generator = test_datagen.flow_from_directory(test_dir,
    target_size=(width_shape, height_shape),
    color_mode="rgb",
    class_mode='categorical',
    batch_size= batch_size)
# Out:
# Found 691 images belonging to 5 classes.

# %%
best_model_results = vgg_model.evaluate(test_generator)
print("Loss: ",best_model_results[0])
print("Accuracy: ", best_model_results[1])
# Out:
# 22/22 [==============================] - 59s 3s/step - loss: 0.3347 - accuracy: 0.8799
# Loss:  0.33465832471847534
# Accuracy:  0.8798842430114746

# %%
# Make predictions on the test data
predictions = vgg_model.predict(test_generator)

# Convert the predicted probabilities to class labels
predicted_labels = np.argmax(predictions, axis=1)

# Get the true labels from the generator object
true_labels = test_generator.classes

# Create a confusion matrix
confusion_mat = confusion_matrix(true_labels, predicted_labels)
# Out:
# 22/22 [==============================] - 52s 2s/step
# [[45 19 12 57 31]
#  [21 16 10 23 24]
#  [18  7  9 17 21]
#  [46 28 18 59 43]
#  [38 20 22 48 39]]

# %%
# Set the figure size
plt.figure(figsize=(10,8))

# Plot the confusion matrix as a heatmap
sns.heatmap(confusion_mat, annot=True, fmt='d', cmap='Blues',xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %%
# Make predictions on the test data
predictions = vgg_model.predict(valid_generator)

# Convert the predicted probabilities to class labels
predicted_labels = np.argmax(predictions, axis=1)

# Get the true labels from the generator object
true_labels = valid_generator.classes

# Create a confusion matrix
confusion_mat = confusion_matrix(true_labels, predicted_labels)
# Out:
# 26/26 [==============================] - 62s 2s/step

# %%
# Set the figure size
plt.figure(figsize=(10,8))

# Plot the confusion matrix as a heatmap
sns.heatmap(confusion_mat, annot=True, fmt='d', cmap='Blues',xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %%
# Make predictions on the test data
predictions = vgg_model.predict(train_generator)

# Convert the predicted probabilities to class labels
predicted_labels = np.argmax(predictions, axis=1)

# Get the true labels from the generator object
true_labels = train_generator.classes

# Create a confusion matrix
confusion_mat = confusion_matrix(true_labels, predicted_labels)
# Out:
#  71/102 [===================>..........] - ETA: 1:22
# C:\Users\danie\OneDrive\Documentos\GitHub\RoomsClassifier\env\lib\site-packages\PIL\Image.py:959: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# 102/102 [==============================] - 280s 3s/step

# %%
# Set the figure size
plt.figure(figsize=(10,8))

# Plot the confusion matrix as a heatmap
sns.heatmap(confusion_mat, annot=True, fmt='d', cmap='Blues',xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
#125,166 62 128 154; 197
